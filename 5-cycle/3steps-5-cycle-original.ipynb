# %%
#pip install qiskit

# %%
#pip install qiskit[visualization]

# %%
import qiskit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer
from qiskit.circuit.library import MCMT
from qiskit.circuit.library import MCMTVChain
from qiskit.quantum_info.operators import Operator, Pauli
import qiskit.quantum_info as qi
import numpy as np
import math as m
#from qiskit.circuit.library.standard_gates import HGate

# %%
creg_c = qiskit.ClassicalRegister(4)
qreg_q = qiskit.QuantumRegister(4)

circuit = qiskit.QuantumCircuit(qreg_q,creg_c)

# %%
circuit.x (qreg_q[1]);
circuit.x (qreg_q[2]);
circuit.h (qreg_q[3]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0 , 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.x (qreg_q[1]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.h (qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[3], qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.x (qreg_q[2]);
circuit.x (qreg_q[0]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.h (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[3], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.ccx (qreg_q[3], qreg_q[1], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.h (qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.x (qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.h (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[3], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.ccx (qreg_q[3], qreg_q[1], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.h (qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.x (qreg_q[0]);
circuit.x (qreg_q[2]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.h (qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[3], qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.x (qreg_q[1]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx(qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu (0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.x (qreg_q[3]);


circuit.h (qreg_q[3]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0 , 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.x (qreg_q[1]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.h (qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[3], qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.x (qreg_q[2]);
circuit.x (qreg_q[0]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.h (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[3], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.ccx (qreg_q[3], qreg_q[1], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.h (qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.x (qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.h (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[3], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.ccx (qreg_q[3], qreg_q[1], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.h (qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.x (qreg_q[0]);
circuit.x (qreg_q[2]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.h (qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[3], qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.x (qreg_q[1]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx(qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu (0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.x (qreg_q[3]);


circuit.h (qreg_q[3]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0 , 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.x (qreg_q[1]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.h (qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[3], qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.x (qreg_q[2]);
circuit.x (qreg_q[0]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.h (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[3], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.ccx (qreg_q[3], qreg_q[1], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.h (qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.x (qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.h (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[3], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.ccx (qreg_q[3], qreg_q[1], qreg_q[2]);
circuit.tdg (qreg_q[2]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[2]);
circuit.t (qreg_q[2]);
circuit.h (qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[3]);
circuit.cx (qreg_q[2], qreg_q[1]);
circuit.x (qreg_q[0]);
circuit.x (qreg_q[2]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.h (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.ccx (qreg_q[3], qreg_q[2], qreg_q[1]);
circuit.tdg (qreg_q[1]);
circuit.ccx (qreg_q[0], qreg_q[2], qreg_q[1]);
circuit.t (qreg_q[1]);
circuit.h (qreg_q[1]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[2], qreg_q[0]);
circuit.cx (qreg_q[3], qreg_q[2]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[3], qreg_q[0]);
circuit.cx (qreg_q[1], qreg_q[0]);
circuit.x (qreg_q[1]);
circuit.h (qreg_q[0]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.t (qreg_q[3]);
circuit.ccx (qreg_q[1], qreg_q[2], qreg_q[3]);
circuit.tdg (qreg_q[3]);
circuit.ccx(qreg_q[1], qreg_q[0], qreg_q[3]);
circuit.cu(0, np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.t (qreg_q[3]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu(0, -np.pi / 4, 0, 0, qreg_q[1], qreg_q[2]);
circuit.cx (qreg_q[0], qreg_q[1]);
circuit.cu (0, np.pi / 4, 0, 0, qreg_q[0], qreg_q[2]);
circuit.h (qreg_q[0]);
circuit.x (qreg_q[3]);
circuit.x (qreg_q[1]);
circuit.x (qreg_q[2]);

circuit.draw('mpl')

# %%
print("Depth: ", circuit.depth())
# Out:
# Depth:  341

# %%
print("Size: ", circuit.size())
# Out:
# Size:  421

# %%
circuit.measure(0, 0)
circuit.measure(1, 1)
circuit.measure(2, 2)

# %%
sim = qiskit.Aer.get_backend('qasm_simulator')
job = qiskit.execute(circuit,sim,shots=1024)
qiskit.visualization.plot_histogram(job.result().get_counts())
