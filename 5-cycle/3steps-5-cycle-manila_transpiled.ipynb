# %%
#pip install qiskit

# %%
#pip install qiskit[visualization]

# %%
import qiskit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer
import numpy as np
import math as m

# %%
creg_c = qiskit.ClassicalRegister(4)
qreg_q = qiskit.QuantumRegister(5)

circuit = qiskit.QuantumCircuit(qreg_q,creg_c)

# %%
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-1.1780972450961738, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.rz(1.178097245096172, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.x(qreg_q[2])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.x(qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.x(qreg_q[2])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[0])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.x(qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.rz(1.178097245096172, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-1.1780972450961738, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[0])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.x(qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(1.178097245096172, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(0.3926990816987237, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-1.1780972450961738, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(0.7853981633974492, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.rz(1.178097245096172, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.x(qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-1.5707963267948966, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.rz(1.178097245096172, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.x(qreg_q[2])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.x(qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(0.7853981633974492, qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.x(qreg_q[2])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.x(qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-1.1780972450961738, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-1.1780972450961738, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-1.1780972450961738, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-1.1780972450961738, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[0])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.x(qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987237, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.x(qreg_q[0])
circuit.rz(-0.7853981633974492, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.3926990816987246, qreg_q[2])
circuit.rz(1.178097245096172, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-1.1780972450961738, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.x(qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.rz(1.178097245096172, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-1.1780972450961738, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-1.5707963267948966, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(-2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987237, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.3926990816987228, qreg_q[2])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.39269908169872414, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(-2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-2.356194490192345, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(1.178097245096172, qreg_q[0])
circuit.x(qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.3926990816987246, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(0.3926990816987237, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-1.1780972450961738, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.3926990816987228, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.39269908169872414, qreg_q[0])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.x(qreg_q[0])
circuit.rz(-0.7853981633974492, qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.x(qreg_q[2])

# %%
print("Depth: ", circuit.depth())
# Out:
# Depth:  2267

# %%
print("Size: ", circuit.size())
# Out:
# Size:  3185

# %%
circuit.measure(qreg_q[1], creg_c[0])
circuit.measure(qreg_q[2], creg_c[1])
circuit.measure(qreg_q[0], creg_c[2])
circuit.draw('mpl')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sim = qiskit.Aer.get_backend('qasm_simulator')
job = qiskit.execute(circuit,sim,shots=1024)
qiskit.visualization.plot_histogram(job.result().get_counts())
