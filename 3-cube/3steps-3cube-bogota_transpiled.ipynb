# %%
#pip install qiskit

# %%
#pip install qiskit[visualization]

# %%
import qiskit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer
import numpy as np
import math as m

# %%
qreg_q = QuantumRegister(5, 'q')
creg_c = ClassicalRegister(5, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.rz(1.5707963267948966, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(-1.5707963267948968, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.rz(-3.141592653589793, qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.rz(-3.141592653589793, qreg_q[4])
circuit.x(qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.x(qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.x(qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-3.141592653589793, qreg_q[1])
circuit.rz(-1.5707963267948963, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-3.141592653589793, qreg_q[1])
circuit.x(qreg_q[1])
circuit.rz(1.5707963267948966, qreg_q[2])
circuit.sx(qreg_q[2])
circuit.rz(-1.5707963267948966, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[3])
circuit.rz(0.7853981633974492, qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.x(qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[0])
circuit.rz(0.7853981633974492, qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974492, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974492, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-3.141592653589793, qreg_q[2])
circuit.rz(-1.5707963267948963, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-3.141592653589793, qreg_q[2])
circuit.x(qreg_q[2])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(-1.5707963267948966, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(-0.7853981633974483, qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.rz(0.7853981633974483, qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[4], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.x(qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[0])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(1.5707963267948966, qreg_q[0])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.x(qreg_q[1])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(-0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.rz(0.7853981633974483, qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.rz(0.7853981633974483, qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[3], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[3])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.rz(-0.7853981633974483, qreg_q[1])
circuit.rz(0.7853981633974483, qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.x(qreg_q[1])
circuit.rz(2.356194490192345, qreg_q[3])
circuit.sx(qreg_q[3])
circuit.rz(1.5707963267948966, qreg_q[3])
circuit.rz(2.356194490192345, qreg_q[4])
circuit.sx(qreg_q[4])
circuit.rz(1.5707963267948966, qreg_q[4])

# %%
print("Depth: ", circuit.depth())
# Out:
# Depth:  195

# %%
print("Size: ", circuit.size())
# Out:
# Size:  280

# %%
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[4], creg_c[1])
circuit.measure(qreg_q[3], creg_c[2])
circuit.draw('mpl')

# %%
sim = qiskit.Aer.get_backend('qasm_simulator')
job = qiskit.execute(circuit,sim,shots=1024)
qiskit.visualization.plot_histogram(job.result().get_counts())
